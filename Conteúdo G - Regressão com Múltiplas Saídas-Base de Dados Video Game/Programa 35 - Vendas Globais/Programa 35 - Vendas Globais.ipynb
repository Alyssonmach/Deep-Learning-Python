# %% [markdown]
# # Estrutura da Rede Neural
# #### Visualizando as vendas globais do jogo.

# %% [markdown]
# Nesse programa, ao invéis de ser feito a previsão em três países distintos, vamos analisar a venda global dos jogos.

# %% [markdown]
# ### Importando as Bibliotecas

# %%
# importando a biblioteca pandas do python
import pandas as pd
# importando a biblioteca keras do python
from keras.layers import Dense, Dropout, Activation, Input
from keras.models import Model
# importando a biblioteca sklearn do python
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Tratando os Dados

# %%
# importando os dados no 'dataframe'
dataframe = pd.read_csv('/content/drive/My Drive/games.csv', encoding = "utf-8", sep = ',')

# %%
# removendo colunas que não será importantes para a estrutura da rede neural
dataframe = dataframe.drop('Other_Sales', axis = 1)
dataframe = dataframe.drop('Developer', axis = 1)
dataframe = dataframe.drop('NA_Sales', axis = 1)
dataframe = dataframe.drop('EU_Sales', axis = 1)
dataframe = dataframe.drop('JP_Sales', axis = 1)

# %%
# apagando os registros com valores faltantes
dataframe = dataframe.dropna(axis = 0)

# %%
# removendo os dados de vendas armazenados com valores inconsistentes
dataframe = dataframe.loc[dataframe['Global_Sales'] > 1]

# %%
# salvando os nomes dos jogos para posterior uso
nome_jogos = dataframe.Name

# %%
# removendo colunas que não serão importantes para a estrutura da rede neural
dataframe = dataframe.drop('Name', axis = 1)

# %%
# separando os atributos previsores dos atributos meta do dataframe
previsores = dataframe.iloc[: , [0, 1, 2, 3, 5, 6, 7, 8, 9]].values
classe = dataframe.iloc[:, 4].values

# %%
# criando o objeto labelencoder
labelencoder = LabelEncoder()

# %%
# transformando os atributos categóricos em atributos numéricos
previsores[:, 0] = labelencoder.fit_transform(previsores[:, 0])
previsores[:, 2] = labelencoder.fit_transform(previsores[:, 2])
previsores[:, 3] = labelencoder.fit_transform(previsores[:, 3])
previsores[:, 8] = labelencoder.fit_transform(previsores[:, 8])

# %%
# transformando os atributos numéricos  em variáveis do tipo dummy
onehotencoder = ColumnTransformer(transformers=[("OneHot", OneHotEncoder(), 
                                                  [0, 2, 3, 8])], 
                                  remainder='passthrough')
previsores = onehotencoder.fit_transform(previsores).toarray()

# %% [markdown]
# ### Configurando a Rede Neural

# %%
# visualizando as dimensões dos atributos previsores e meta
print(previsores.shape)
print(classe.shape)
# Out:
# (1307, 99)
# (1307,)

# %%
# definindo a camada de entrada com 99 neurônios
camada_entrada = Input(shape = (99,))
# definindo uma função de ativação sigmoid
ativacao = Activation(activation = 'sigmoid')
# definindo a primeira camada oculta
camada_oculta1 = Dense(units = 50, activation = ativacao)(camada_entrada)
# definindo a segunda camada oculta
camada_oculta2 = Dense(units = 50, activation = ativacao)(camada_oculta1)
# definindo uma camada de saída
camada_saida = Dense(units = 1, activation = 'linear')(camada_oculta2)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/activations.py:235: UserWarning: Do not pass a layer instance (such as Activation) as the activation argument of another layer. Instead, advanced activation layers should be used just like any other layer in a model.
#   identifier=identifier.__class__.__name__))

# %%
# definindo o modelo da rede neural
regressor = Model(inputs = camada_entrada, outputs = [camada_saida])

# %%
# definindo alguns parâmetros da rede neural
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %% [markdown]
# ### Treinando a Rede Neural

# %%
# treinando a rede neural
regressor.fit(previsores, classe, epochs = 5000, batch_size = 100, verbose = False)

# %% [markdown]
# ### Prevendo Valores com a Rede Neural

# %%
# realizando a previsão com a rede neural
previsoes = regressor.predict(previsores)

# %%
for i in range(0, len(previsoes)):
  print('Algoritmo: {} | Original: {}'.format(previsoes[i], classe[i]))
# Out:
# Algoritmo: [2.435533] | Original: 82.53
# Algoritmo: [2.435533] | Original: 35.52
# Algoritmo: [2.4355555] | Original: 32.77
# Algoritmo: [2.4355369] | Original: 29.8
# Algoritmo: [2.435533] | Original: 28.92
# Algoritmo: [2.4355392] | Original: 28.32
# Algoritmo: [2.4355512] | Original: 23.21
# Algoritmo: [2.4355435] | Original: 22.7
# Algoritmo: [2.435533] | Original: 21.81
# Algoritmo: [2.4355335] | Original: 21.79
# Algoritmo: [4.8384943] | Original: 21.04
# Algoritmo: [4.8384943] | Original: 20.81
# Algoritmo: [2.4355345] | Original: 20.15
# Algoritmo: [4.8384943] | Original: 16.27
# Algoritmo: [2.435533] | Original: 16.15
# Algoritmo: [2.435533] | Original: 15.29
# Algoritmo: [2.435536] | Original: 14.98
# Algoritmo: [4.6642284] | Original: 14.73
# Algoritmo: [4.8384943] | Original: 14.61
# Algoritmo: [2.435533] | Original: 13.79
# Algoritmo: [4.8384943] | Original: 13.67
# Algoritmo: [4.8384943] | Original: 13.47
# Algoritmo: [4.8384943] | Original: 13.32
# Algoritmo: [2.435533] | Original: 13.1
# Algoritmo: [4.8384943] | Original: 12.84
# Algoritmo: [2.435533] | Original: 12.66
# Algoritmo: [2.436177] | Original: 12.63
# Algoritmo: [4.8384943] | Original: 12.61
# Algoritmo: [2.4355333] | Original: 12.13
# Algoritmo: [4.8384943] | Original: 12.12
# Algoritmo: [2.4355345] | Original: 11.66
# Algoritmo: [4.8384943] | Original: 11.35
# Algoritmo: [4.8384943] | Original: 11.01
# Algoritmo: [2.4355345] | Original: 10.95
# Algoritmo: [2.435533] | Original: 10.81
# Algoritmo: [2.4355438] | Original: 10.7
# Algoritmo: [4.8384943] | Original: 10.6
# Algoritmo: [4.8384943] | Original: 10.5
# Algoritmo: [4.8384943] | Original: 10.25
# Algoritmo: [2.435533] | Original: 10.12
# Algoritmo: [2.435533] | Original: 9.9
# Algoritmo: [4.8384943] | Original: 9.86
# Algoritmo: [4.8384943] | Original: 9.72
# Algoritmo: [4.8384943] | Original: 9.71
# Algoritmo: [2.435533] | Original: 9.49
# Algoritmo: [2.435533] | Original: 9.44
# Algoritmo: [2.4355407] | Original: 9.36
# Algoritmo: [4.8384943] | Original: 9.31
# Algoritmo: [2.435533] | Original: 9.16
# Algoritmo: [2.435533] | Original: 8.91
# Algoritmo: [4.8384943] | Original: 8.79
# Algoritmo: [2.435533] | Original: 8.57
# Algoritmo: [4.8384943] | Original: 8.49
# Algoritmo: [2.435533] | Original: 8.38
# Algoritmo: [2.435533] | Original: 8.27
# Algoritmo: [2.435533] | Original: 8.16
# Algoritmo: [2.435533] | Original: 8.05
# Algoritmo: [2.435533] | Original: 8.01
# Algoritmo: [2.435533] | Original: 7.86
# Algoritmo: [2.435533] | Original: 7.72
# Algoritmo: [2.435533] | Original: 7.69
# Algoritmo: [4.8384943] | Original: 7.66
# Algoritmo: [2.4355323] | Original: 7.59
# Algoritmo: [4.8384953] | Original: 7.51
# Algoritmo: [2.435533] | Original: 7.38
# Algoritmo: [4.8384943] | Original: 7.32
# Algoritmo: [2.435533] | Original: 7.2
# Algoritmo: [2.435533] | Original: 7.2
# Algoritmo: [4.8384943] | Original: 7.17
# Algoritmo: [4.8384943] | Original: 7.16
# Algoritmo: [2.435533] | Original: 7.16
# Algoritmo: [4.8384943] | Original: 7.15
# Algoritmo: [2.435533] | Original: 7.13
# Algoritmo: [4.8384943] | Original: 7.09
# Algoritmo: [2.435533] | Original: 7.07
# Algoritmo: [2.435533] | Original: 6.9
# Algoritmo: [2.435533] | Original: 6.83
# Algoritmo: [2.435533] | Original: 6.76
# Algoritmo: [4.8384943] | Original: 6.75
# Algoritmo: [4.8384943] | Original: 6.74
# Algoritmo: [2.435533] | Original: 6.68
# Algoritmo: [4.8384943] | Original: 6.66
# Algoritmo: [2.435533] | Original: 6.62
# Algoritmo: [4.8384943] | Original: 6.49
# Algoritmo: [2.435533] | Original: 6.47
# Algoritmo: [4.8384943] | Original: 6.45
# Algoritmo: [2.4355512] | Original: 6.44
# Algoritmo: [4.8384943] | Original: 6.43
# Algoritmo: [4.8384943] | Original: 6.41
# Algoritmo: [2.435533] | Original: 6.41
# Algoritmo: [2.435533] | Original: 6.4
# Algoritmo: [4.778304] | Original: 6.34
# Algoritmo: [4.8384943] | Original: 6.32
# Algoritmo: [2.435533] | Original: 6.31
# Algoritmo: [4.8384943] | Original: 6.29
# Algoritmo: [2.4355323] | Original: 6.27
# Algoritmo: [4.8384943] | Original: 6.21
# Algoritmo: [2.435533] | Original: 6.19
# Algoritmo: [4.8384943] | Original: 6.09
# Algoritmo: [2.435533] | Original: 6.08
# Algoritmo: [2.435533] | Original: 6.05
# Algoritmo: [2.435533] | Original: 6.03
# Algoritmo: [4.8384943] | Original: 5.99
# Algoritmo: [2.435533] | Original: 5.95
# Algoritmo: [4.6642284] | Original: 5.87
# Algoritmo: [4.8384943] | Original: 5.82
# Algoritmo: [2.435533] | Original: 5.82
# Algoritmo: [2.435533] | Original: 5.78
# Algoritmo: [2.435533] | Original: 5.74
# Algoritmo: [4.8384943] | Original: 5.64
# Algoritmo: [2.435533] | Original: 5.64
# Algoritmo: [2.435533] | Original: 5.63
# Algoritmo: [4.8384914] | Original: 5.55
# Algoritmo: [2.435533] | Original: 5.54
# Algoritmo: [2.435533] | Original: 5.49
# Algoritmo: [2.435533] | Original: 5.49
# Algoritmo: [2.435533] | Original: 5.48
# Algoritmo: [4.8384943] | Original: 5.48
# Algoritmo: [2.435533] | Original: 5.48
# Algoritmo: [2.435533] | Original: 5.47
# Algoritmo: [2.435533] | Original: 5.42
# Algoritmo: [2.435533] | Original: 5.39
# Algoritmo: [4.6642284] | Original: 5.38
# Algoritmo: [4.8384943] | Original: 5.33
# Algoritmo: [2.435533] | Original: 5.3
# Algoritmo: [4.8384924] | Original: 5.29
# Algoritmo: [2.4355323] | Original: 5.29
# Algoritmo: [2.4355323] | Original: 5.27
# Algoritmo: [4.8384943] | Original: 5.26
# Algoritmo: [2.435533] | Original: 5.22
# Algoritmo: [2.435533] | Original: 5.21
# Algoritmo: [2.435574] | Original: 5.19
# Algoritmo: [2.435533] | Original: 5.16
# Algoritmo: [4.6642284] | Original: 5.14
# Algoritmo: [2.435533] | Original: 5.13
# Algoritmo: [2.4355335] | Original: 5.12
# Algoritmo: [2.435533] | Original: 5.1
# Algoritmo: [2.435533] | Original: 5.09
# Algoritmo: [2.435533] | Original: 5.08
# Algoritmo: [2.435533] | Original: 5.07
# Algoritmo: [2.435533] | Original: 5.05
# Algoritmo: [2.435533] | Original: 5.03
# Algoritmo: [2.435533] | Original: 5.02
# Algoritmo: [2.435533] | Original: 4.98
# Algoritmo: [2.435533] | Original: 4.98
# Algoritmo: [4.8384943] | Original: 4.93
# Algoritmo: [4.8384943] | Original: 4.92
# Algoritmo: [2.435533] | Original: 4.91
# Algoritmo: [4.8384943] | Original: 4.84
# Algoritmo: [2.435533] | Original: 4.82
# Algoritmo: [4.8384943] | Original: 4.8
# Algoritmo: [2.435533] | Original: 4.79
# Algoritmo: [2.435533] | Original: 4.76
# Algoritmo: [2.435533] | Original: 4.73
# Algoritmo: [4.8384943] | Original: 4.73
# Algoritmo: [2.4355333] | Original: 4.68
# Algoritmo: [2.435533] | Original: 4.67
# Algoritmo: [2.435533] | Original: 4.63
# Algoritmo: [2.4355323] | Original: 4.62
# Algoritmo: [4.8384943] | Original: 4.62
# Algoritmo: [2.435533] | Original: 4.6
# Algoritmo: [2.435533] | Original: 4.6
# Algoritmo: [2.435533] | Original: 4.59
# Algoritmo: [2.435533] | Original: 4.57
# Algoritmo: [2.435533] | Original: 4.53
# Algoritmo: [2.435533] | Original: 4.53
# Algoritmo: [2.435533] | Original: 4.49
# Algoritmo: [4.8384943] | Original: 4.48
# Algoritmo: [2.435533] | Original: 4.48
# Algoritmo: [2.4384847] | Original: 4.46
# Algoritmo: [2.435533] | Original: 4.45
# Algoritmo: [4.826207] | Original: 4.43
# Algoritmo: [2.435533] | Original: 4.42
# Algoritmo: [2.435533] | Original: 4.41
# Algoritmo: [2.435533] | Original: 4.39
# Algoritmo: [2.4355812] | Original: 4.38
# Algoritmo: [2.435533] | Original: 4.37
# Algoritmo: [2.435533] | Original: 4.36
# Algoritmo: [2.435533] | Original: 4.34
# Algoritmo: [2.435533] | Original: 4.33
# Algoritmo: [4.8384943] | Original: 4.32
# Algoritmo: [4.8384943] | Original: 4.27
# Algoritmo: [2.435533] | Original: 4.24
# Algoritmo: [2.4363883] | Original: 4.23
# Algoritmo: [2.435533] | Original: 4.23
# Algoritmo: [2.435533] | Original: 4.22
# Algoritmo: [4.8384943] | Original: 4.22
# Algoritmo: [2.435533] | Original: 4.22
# Algoritmo: [2.435533] | Original: 4.21
# Algoritmo: [2.435533] | Original: 4.21
# Algoritmo: [2.4355323] | Original: 4.2
# Algoritmo: [2.4355323] | Original: 4.19
# Algoritmo: [2.435533] | Original: 4.19
# Algoritmo: [2.435533] | Original: 4.16
# Algoritmo: [2.4355335] | Original: 4.14
# Algoritmo: [4.8384943] | Original: 4.12
# Algoritmo: [2.435533] | Original: 4.09
# Algoritmo: [2.435533] | Original: 4.08
# Algoritmo: [2.435533] | Original: 4.07
# Algoritmo: [2.435533] | Original: 4.05
# Algoritmo: [2.435533] | Original: 4.05
# Algoritmo: [2.435533] | Original: 4.05
# Algoritmo: [4.8384943] | Original: 4.05
# Algoritmo: [2.435533] | Original: 4.05
# Algoritmo: [4.8384943] | Original: 4.04
# Algoritmo: [2.435533] | Original: 3.97
# Algoritmo: [4.6642284] | Original: 3.97
# Algoritmo: [4.8384943] | Original: 3.96
# Algoritmo: [4.8384943] | Original: 3.95
# Algoritmo: [4.8384943] | Original: 3.95
# Algoritmo: [2.435533] | Original: 3.94
# Algoritmo: [2.435533] | Original: 3.94
# Algoritmo: [2.435533] | Original: 3.9
# Algoritmo: [2.435533] | Original: 3.9
# Algoritmo: [2.435533] | Original: 3.89
# Algoritmo: [4.6642284] | Original: 3.88
# Algoritmo: [2.435533] | Original: 3.88
# Algoritmo: [2.435533] | Original: 3.87
# Algoritmo: [2.435533] | Original: 3.87
# Algoritmo: [2.435533] | Original: 3.85
# Algoritmo: [2.435533] | Original: 3.84
# Algoritmo: [4.8384943] | Original: 3.83
# Algoritmo: [2.4355323] | Original: 3.83
# Algoritmo: [4.8384943] | Original: 3.8
# Algoritmo: [2.435533] | Original: 3.79
# Algoritmo: [2.435533] | Original: 3.76
# Algoritmo: [2.435533] | Original: 3.76
# Algoritmo: [2.435533] | Original: 3.73
# Algoritmo: [2.4355333] | Original: 3.71
# Algoritmo: [2.435533] | Original: 3.71
# Algoritmo: [2.435533] | Original: 3.71
# Algoritmo: [2.435533] | Original: 3.7
# Algoritmo: [2.435533] | Original: 3.67
# Algoritmo: [2.435533] | Original: 3.66
# Algoritmo: [2.435533] | Original: 3.65
# Algoritmo: [2.435533] | Original: 3.65
# Algoritmo: [2.435533] | Original: 3.64
# Algoritmo: [2.435533] | Original: 3.63
# Algoritmo: [2.435533] | Original: 3.62
# Algoritmo: [2.435533] | Original: 3.62
# Algoritmo: [2.435533] | Original: 3.62
# Algoritmo: [2.435533] | Original: 3.61
# Algoritmo: [2.435533] | Original: 3.61
# Algoritmo: [2.435533] | Original: 3.6
# Algoritmo: [4.8384943] | Original: 3.59
# Algoritmo: [2.435533] | Original: 3.59
# Algoritmo: [2.435533] | Original: 3.58
# Algoritmo: [2.435533] | Original: 3.54
# Algoritmo: [2.435533] | Original: 3.54
# Algoritmo: [2.435533] | Original: 3.53
# Algoritmo: [2.435533] | Original: 3.52
# Algoritmo: [4.8384943] | Original: 3.51
# Algoritmo: [2.435533] | Original: 3.5
# Algoritmo: [2.435533] | Original: 3.5
# Algoritmo: [2.4355323] | Original: 3.49
# Algoritmo: [2.4355323] | Original: 3.49
# Algoritmo: [2.435533] | Original: 3.48
# Algoritmo: [2.435533] | Original: 3.48
# Algoritmo: [2.435533] | Original: 3.47
# Algoritmo: [2.435533] | Original: 3.46
# Algoritmo: [2.435534] | Original: 3.45
# Algoritmo: [2.435533] | Original: 3.44
# Algoritmo: [2.435533] | Original: 3.44
# Algoritmo: [2.435533] | Original: 3.42
# Algoritmo: [4.8384943] | Original: 3.41
# Algoritmo: [2.435533] | Original: 3.41
# Algoritmo: [2.435533] | Original: 3.4
# Algoritmo: [2.435533] | Original: 3.39
# Algoritmo: [2.435533] | Original: 3.39
# Algoritmo: [4.8384943] | Original: 3.39
# Algoritmo: [2.435533] | Original: 3.38
# Algoritmo: [4.8384943] | Original: 3.37
# Algoritmo: [2.435533] | Original: 3.35
# Algoritmo: [2.435533] | Original: 3.33
# Algoritmo: [2.435533] | Original: 3.32
# Algoritmo: [2.435533] | Original: 3.31
# Algoritmo: [2.435533] | Original: 3.31
# Algoritmo: [2.435533] | Original: 3.3
# Algoritmo: [2.435533] | Original: 3.28
# Algoritmo: [2.435533] | Original: 3.28
# Algoritmo: [2.435533] | Original: 3.27
# Algoritmo: [2.435533] | Original: 3.26
# Algoritmo: [2.435533] | Original: 3.25
# Algoritmo: [2.435533] | Original: 3.25
# Algoritmo: [2.435533] | Original: 3.24
# Algoritmo: [2.435533] | Original: 3.23
# Algoritmo: [4.8384943] | Original: 3.23
# Algoritmo: [2.4355323] | Original: 3.21
# Algoritmo: [2.435533] | Original: 3.18
# Algoritmo: [2.435533] | Original: 3.18
# Algoritmo: [2.435533] | Original: 3.18
# Algoritmo: [2.435533] | Original: 3.17
# Algoritmo: [2.435533] | Original: 3.17
# Algoritmo: [2.435533] | Original: 3.17
# Algoritmo: [2.435533] | Original: 3.15
# Algoritmo: [2.435533] | Original: 3.14
# Algoritmo: [2.435533] | Original: 3.13
# Algoritmo: [2.435533] | Original: 3.13
# Algoritmo: [2.435533] | Original: 3.12
# Algoritmo: [2.4355385] | Original: 3.11
# Algoritmo: [2.435533] | Original: 3.11
# Algoritmo: [2.435533] | Original: 3.11
# Algoritmo: [2.435533] | Original: 3.1
# Algoritmo: [2.435533] | Original: 3.1
# Algoritmo: [4.8384943] | Original: 3.1
# Algoritmo: [4.8384943] | Original: 3.1
# Algoritmo: [2.435533] | Original: 3.09
# Algoritmo: [2.4355333] | Original: 3.08
# Algoritmo: [2.435533] | Original: 3.07
# Algoritmo: [2.435533] | Original: 3.05
# Algoritmo: [4.8384943] | Original: 3.05
# Algoritmo: [2.435533] | Original: 3.05
# Algoritmo: [2.435533] | Original: 3.05
# Algoritmo: [2.435533] | Original: 3.04
# Algoritmo: [4.8384943] | Original: 3.04
# Algoritmo: [4.8384943] | Original: 3.03
# Algoritmo: [2.435533] | Original: 3.03
# Algoritmo: [2.435533] | Original: 3.02
# Algoritmo: [2.4355323] | Original: 3.01
# Algoritmo: [4.8384943] | Original: 3.01
# Algoritmo: [4.8384943] | Original: 3.0
# Algoritmo: [2.435533] | Original: 3.0
# Algoritmo: [2.435533] | Original: 3.0
# Algoritmo: [2.435533] | Original: 3.0
# Algoritmo: [2.435533] | Original: 2.99
# Algoritmo: [2.435533] | Original: 2.99
# Algoritmo: [2.435533] | Original: 2.99
# Algoritmo: [4.8384943] | Original: 2.96
# Algoritmo: [4.8384943] | Original: 2.96
# Algoritmo: [2.435533] | Original: 2.96
# Algoritmo: [2.435533] | Original: 2.96
# Algoritmo: [4.8384943] | Original: 2.95
# Algoritmo: [2.435533] | Original: 2.95
# Algoritmo: [2.435533] | Original: 2.94
# Algoritmo: [2.435533] | Original: 2.94
# Algoritmo: [2.435533] | Original: 2.94
# Algoritmo: [2.5546253] | Original: 2.93
# Algoritmo: [2.435533] | Original: 2.92
# Algoritmo: [2.435533] | Original: 2.92
# Algoritmo: [4.8384943] | Original: 2.91
# Algoritmo: [2.435533] | Original: 2.9
# Algoritmo: [2.4355333] | Original: 2.9
# Algoritmo: [2.435533] | Original: 2.89
# Algoritmo: [2.435533] | Original: 2.89
# Algoritmo: [2.435533] | Original: 2.89
# Algoritmo: [2.435533] | Original: 2.89
# Algoritmo: [2.435533] | Original: 2.89
# Algoritmo: [2.435533] | Original: 2.86
# Algoritmo: [2.435533] | Original: 2.86
# Algoritmo: [4.8384943] | Original: 2.85
# Algoritmo: [2.4355323] | Original: 2.84
# Algoritmo: [2.4355323] | Original: 2.83
# Algoritmo: [4.8384943] | Original: 2.83
# Algoritmo: [2.435533] | Original: 2.82
# Algoritmo: [2.435533] | Original: 2.82
# Algoritmo: [2.435533] | Original: 2.81
# Algoritmo: [4.8384943] | Original: 2.79
# Algoritmo: [2.435533] | Original: 2.79
# Algoritmo: [2.435533] | Original: 2.78
# Algoritmo: [2.435533] | Original: 2.78
# Algoritmo: [2.435533] | Original: 2.78
# Algoritmo: [4.8384943] | Original: 2.78
# Algoritmo: [2.435533] | Original: 2.78
# Algoritmo: [2.435533] | Original: 2.77
# Algoritmo: [2.435533] | Original: 2.77
# Algoritmo: [2.435533] | Original: 2.77
# Algoritmo: [2.435533] | Original: 2.76
# Algoritmo: [2.435533] | Original: 2.76
# Algoritmo: [2.435533] | Original: 2.75
# Algoritmo: [2.435533] | Original: 2.73
# Algoritmo: [2.435533] | Original: 2.7
# Algoritmo: [2.435533] | Original: 2.7
# Algoritmo: [2.435533] | Original: 2.7
# Algoritmo: [2.435533] | Original: 2.7
# Algoritmo: [2.435533] | Original: 2.69
# Algoritmo: [2.435533] | Original: 2.69
# Algoritmo: [4.8384943] | Original: 2.69
# Algoritmo: [2.435533] | Original: 2.69
# Algoritmo: [2.435533] | Original: 2.68
# Algoritmo: [2.4355333] | Original: 2.67
# Algoritmo: [2.435533] | Original: 2.67
# Algoritmo: [2.435533] | Original: 2.67
# Algoritmo: [2.4355323] | Original: 2.67
# Algoritmo: [2.4355323] | Original: 2.66
# Algoritmo: [2.435533] | Original: 2.66
# Algoritmo: [2.435533] | Original: 2.65
# Algoritmo: [2.435533] | Original: 2.65
# Algoritmo: [2.435533] | Original: 2.65
# Algoritmo: [2.435533] | Original: 2.65
# Algoritmo: [2.435533] | Original: 2.63
# Algoritmo: [2.435533] | Original: 2.63
# Algoritmo: [2.435533] | Original: 2.63
# Algoritmo: [2.435533] | Original: 2.62
# Algoritmo: [2.435533] | Original: 2.62
# Algoritmo: [2.435533] | Original: 2.62
# Algoritmo: [2.435533] | Original: 2.62
# Algoritmo: [2.435533] | Original: 2.61
# Algoritmo: [2.435533] | Original: 2.61
# Algoritmo: [2.435533] | Original: 2.6
# Algoritmo: [2.435533] | Original: 2.59
# Algoritmo: [2.435533] | Original: 2.58
# Algoritmo: [2.435533] | Original: 2.58
# Algoritmo: [2.435533] | Original: 2.58
# Algoritmo: [2.435533] | Original: 2.58
# Algoritmo: [2.435533] | Original: 2.57
# Algoritmo: [2.435533] | Original: 2.57
# Algoritmo: [2.435533] | Original: 2.57
# Algoritmo: [2.435533] | Original: 2.56
# Algoritmo: [2.435533] | Original: 2.56
# Algoritmo: [2.435533] | Original: 2.56
# Algoritmo: [2.435533] | Original: 2.54
# Algoritmo: [2.435533] | Original: 2.54
# Algoritmo: [2.435533] | Original: 2.53
# Algoritmo: [2.435533] | Original: 2.52
# Algoritmo: [2.4355323] | Original: 2.52
# Algoritmo: [2.4355323] | Original: 2.52
# Algoritmo: [2.435533] | Original: 2.52
# Algoritmo: [2.435533] | Original: 2.5
# Algoritmo: [2.435533] | Original: 2.5
# Algoritmo: [2.435533] | Original: 2.49
# Algoritmo: [2.435533] | Original: 2.48
# Algoritmo: [4.6642284] | Original: 2.48
# Algoritmo: [2.435533] | Original: 2.47
# Algoritmo: [2.435533] | Original: 2.47
# Algoritmo: [2.435533] | Original: 2.47
# Algoritmo: [2.435533] | Original: 2.47
# Algoritmo: [4.8384943] | Original: 2.46
# Algoritmo: [2.435533] | Original: 2.45
# Algoritmo: [2.435533] | Original: 2.45
# Algoritmo: [2.435533] | Original: 2.45
# Algoritmo: [2.435533] | Original: 2.43
# Algoritmo: [2.435533] | Original: 2.43
# Algoritmo: [2.435533] | Original: 2.42
# Algoritmo: [2.435533] | Original: 2.42
# Algoritmo: [2.435533] | Original: 2.42
# Algoritmo: [2.435533] | Original: 2.42
# Algoritmo: [2.435533] | Original: 2.41
# Algoritmo: [2.435533] | Original: 2.41
# Algoritmo: [2.435533] | Original: 2.41
# Algoritmo: [2.435533] | Original: 2.41
# Algoritmo: [2.435533] | Original: 2.4
# Algoritmo: [2.435533] | Original: 2.38
# Algoritmo: [2.435533] | Original: 2.38
# Algoritmo: [2.435533] | Original: 2.37
# Algoritmo: [4.6642284] | Original: 2.37
# Algoritmo: [2.435533] | Original: 2.37
# Algoritmo: [2.4355323] | Original: 2.37
# Algoritmo: [2.4355323] | Original: 2.37
# Algoritmo: [2.435533] | Original: 2.37
# Algoritmo: [2.435533] | Original: 2.37
# Algoritmo: [2.435533] | Original: 2.35
# Algoritmo: [2.435533] | Original: 2.35
# Algoritmo: [2.435533] | Original: 2.34
# Algoritmo: [2.435533] | Original: 2.34
# Algoritmo: [2.435533] | Original: 2.34
# Algoritmo: [2.435533] | Original: 2.34
# Algoritmo: [2.435533] | Original: 2.34
# Algoritmo: [2.435533] | Original: 2.31
# Algoritmo: [2.435533] | Original: 2.31
# Algoritmo: [4.8384943] | Original: 2.31
# Algoritmo: [2.435533] | Original: 2.3
# Algoritmo: [2.435533] | Original: 2.29
# Algoritmo: [2.435533] | Original: 2.29
# Algoritmo: [2.435533] | Original: 2.28
# Algoritmo: [2.435533] | Original: 2.28
# Algoritmo: [2.435533] | Original: 2.28
# Algoritmo: [2.435533] | Original: 2.28
# Algoritmo: [2.435533] | Original: 2.28
# Algoritmo: [2.435533] | Original: 2.28
# Algoritmo: [2.435533] | Original: 2.27
# Algoritmo: [2.435533] | Original: 2.27
# Algoritmo: [2.435533] | Original: 2.26
# Algoritmo: [2.435533] | Original: 2.26
# Algoritmo: [2.435533] | Original: 2.26
# Algoritmo: [2.435533] | Original: 2.25
# Algoritmo: [2.435533] | Original: 2.25
# Algoritmo: [2.435533] | Original: 2.25
# Algoritmo: [2.435533] | Original: 2.25
# Algoritmo: [2.4355323] | Original: 2.25
# Algoritmo: [2.4355323] | Original: 2.24
# Algoritmo: [2.435533] | Original: 2.24
# Algoritmo: [2.435533] | Original: 2.24
# Algoritmo: [2.435533] | Original: 2.24
# Algoritmo: [2.435533] | Original: 2.23
# Algoritmo: [2.435533] | Original: 2.23
# Algoritmo: [2.435533] | Original: 2.23
# Algoritmo: [2.435533] | Original: 2.23
# Algoritmo: [2.435533] | Original: 2.22
# Algoritmo: [2.435533] | Original: 2.22
# Algoritmo: [2.435533] | Original: 2.22
# Algoritmo: [2.435533] | Original: 2.21
# Algoritmo: [2.435533] | Original: 2.21
# Algoritmo: [2.435533] | Original: 2.2
# Algoritmo: [2.435533] | Original: 2.2
# Algoritmo: [2.435533] | Original: 2.2
# Algoritmo: [2.435533] | Original: 2.2
# Algoritmo: [2.435533] | Original: 2.2
# Algoritmo: [2.435533] | Original: 2.2
# Algoritmo: [2.435533] | Original: 2.19
# Algoritmo: [2.435533] | Original: 2.19
# Algoritmo: [2.435533] | Original: 2.19
# Algoritmo: [2.435533] | Original: 2.18
# Algoritmo: [2.435533] | Original: 2.18
# Algoritmo: [2.435533] | Original: 2.18
# Algoritmo: [2.435533] | Original: 2.16
# Algoritmo: [2.435533] | Original: 2.16
# Algoritmo: [2.435533] | Original: 2.16
# Algoritmo: [2.435533] | Original: 2.16
# Algoritmo: [2.435533] | Original: 2.16
# Algoritmo: [2.435533] | Original: 2.15
# Algoritmo: [4.8384943] | Original: 2.14
# Algoritmo: [2.4355323] | Original: 2.14
# Algoritmo: [2.435533] | Original: 2.13
# Algoritmo: [2.435533] | Original: 2.13
# Algoritmo: [2.435533] | Original: 2.13
# Algoritmo: [2.435533] | Original: 2.12
# Algoritmo: [2.435533] | Original: 2.12
# Algoritmo: [2.435533] | Original: 2.11
# Algoritmo: [2.435533] | Original: 2.11
# Algoritmo: [2.435533] | Original: 2.11
# Algoritmo: [2.435533] | Original: 2.11
# Algoritmo: [2.435533] | Original: 2.1
# Algoritmo: [2.4355423] | Original: 2.1
# Algoritmo: [2.435533] | Original: 2.1
# Algoritmo: [2.435533] | Original: 2.1
# Algoritmo: [2.435533] | Original: 2.09
# Algoritmo: [2.435533] | Original: 2.09
# Algoritmo: [2.435533] | Original: 2.09
# Algoritmo: [4.8384943] | Original: 2.09
# Algoritmo: [2.435533] | Original: 2.08
# Algoritmo: [2.435533] | Original: 2.08
# Algoritmo: [2.435533] | Original: 2.08
# Algoritmo: [2.435533] | Original: 2.08
# Algoritmo: [2.435533] | Original: 2.08
# Algoritmo: [2.435533] | Original: 2.08
# Algoritmo: [2.435533] | Original: 2.08
# Algoritmo: [2.435533] | Original: 2.07
# Algoritmo: [2.435533] | Original: 2.07
# Algoritmo: [2.435533] | Original: 2.07
# Algoritmo: [4.8384943] | Original: 2.07
# Algoritmo: [2.435533] | Original: 2.06
# Algoritmo: [2.435533] | Original: 2.06
# Algoritmo: [2.4355323] | Original: 2.06
# Algoritmo: [2.4355323] | Original: 2.06
# Algoritmo: [2.435533] | Original: 2.05
# Algoritmo: [2.435533] | Original: 2.05
# Algoritmo: [2.435533] | Original: 2.05
# Algoritmo: [2.435533] | Original: 2.04
# Algoritmo: [2.435533] | Original: 2.04
# Algoritmo: [2.435533] | Original: 2.04
# Algoritmo: [2.435533] | Original: 2.04
# Algoritmo: [2.435533] | Original: 2.04
# Algoritmo: [2.435533] | Original: 2.03
# Algoritmo: [2.435533] | Original: 2.03
# Algoritmo: [2.435533] | Original: 2.03
# Algoritmo: [2.435533] | Original: 2.03
# Algoritmo: [2.435533] | Original: 2.02
# Algoritmo: [4.8384943] | Original: 2.02
# Algoritmo: [2.435533] | Original: 2.02
# Algoritmo: [2.435533] | Original: 2.02
# Algoritmo: [2.4382904] | Original: 2.01
# Algoritmo: [2.435533] | Original: 2.01
# Algoritmo: [4.8384943] | Original: 2.01
# Algoritmo: [2.435533] | Original: 2.0
# Algoritmo: [2.435533] | Original: 2.0
# Algoritmo: [2.435533] | Original: 2.0
# Algoritmo: [2.435533] | Original: 1.99
# Algoritmo: [2.435533] | Original: 1.99
# Algoritmo: [2.435533] | Original: 1.98
# Algoritmo: [2.435533] | Original: 1.98
# Algoritmo: [2.435533] | Original: 1.98
# Algoritmo: [2.435533] | Original: 1.97
# Algoritmo: [2.435533] | Original: 1.97
# Algoritmo: [2.435533] | Original: 1.96
# Algoritmo: [2.4355323] | Original: 1.96
# Algoritmo: [2.4355323] | Original: 1.95
# Algoritmo: [2.435533] | Original: 1.95
# Algoritmo: [4.8384943] | Original: 1.95
# Algoritmo: [2.435533] | Original: 1.95
# Algoritmo: [2.435533] | Original: 1.95
# Algoritmo: [2.435533] | Original: 1.94
# Algoritmo: [2.435533] | Original: 1.94
# Algoritmo: [2.435533] | Original: 1.94
# Algoritmo: [2.435533] | Original: 1.94
# Algoritmo: [2.435533] | Original: 1.94
# Algoritmo: [2.435533] | Original: 1.94
# Algoritmo: [2.435533] | Original: 1.94
# Algoritmo: [2.435533] | Original: 1.94
# Algoritmo: [4.8384943] | Original: 1.93
# Algoritmo: [2.435533] | Original: 1.93
# Algoritmo: [2.435533] | Original: 1.93
# Algoritmo: [2.435533] | Original: 1.93
# Algoritmo: [2.435533] | Original: 1.92
# Algoritmo: [2.435533] | Original: 1.92
# Algoritmo: [2.435533] | Original: 1.92
# Algoritmo: [2.435533] | Original: 1.92
# Algoritmo: [2.435533] | Original: 1.92
# Algoritmo: [2.435533] | Original: 1.92
# Algoritmo: [2.435533] | Original: 1.91
# Algoritmo: [2.435533] | Original: 1.91
# Algoritmo: [2.435533] | Original: 1.91
# Algoritmo: [2.435533] | Original: 1.9
# Algoritmo: [2.435533] | Original: 1.89
# Algoritmo: [2.435533] | Original: 1.89
# Algoritmo: [2.435533] | Original: 1.88
# Algoritmo: [2.435533] | Original: 1.88
# Algoritmo: [2.4355323] | Original: 1.88
# Algoritmo: [2.4355323] | Original: 1.88
# Algoritmo: [2.435533] | Original: 1.88
# Algoritmo: [2.435533] | Original: 1.88
# Algoritmo: [2.435533] | Original: 1.87
# Algoritmo: [2.435533] | Original: 1.87
# Algoritmo: [2.435533] | Original: 1.87
# Algoritmo: [2.435533] | Original: 1.86
# Algoritmo: [2.435533] | Original: 1.86
# Algoritmo: [2.435533] | Original: 1.86
# Algoritmo: [2.435533] | Original: 1.86
# Algoritmo: [2.435533] | Original: 1.86
# Algoritmo: [2.435533] | Original: 1.86
# Algoritmo: [2.435533] | Original: 1.86
# Algoritmo: [2.435533] | Original: 1.85
# Algoritmo: [2.435533] | Original: 1.85
# Algoritmo: [2.435533] | Original: 1.85
# Algoritmo: [2.435533] | Original: 1.84
# Algoritmo: [2.435533] | Original: 1.84
# Algoritmo: [2.435533] | Original: 1.84
# Algoritmo: [2.435533] | Original: 1.83
# Algoritmo: [2.435533] | Original: 1.83
# Algoritmo: [2.435533] | Original: 1.83
# Algoritmo: [2.435533] | Original: 1.82
# Algoritmo: [4.8384943] | Original: 1.82
# Algoritmo: [2.435533] | Original: 1.82
# Algoritmo: [2.435533] | Original: 1.82
# Algoritmo: [4.8384943] | Original: 1.82
# Algoritmo: [2.435533] | Original: 1.82
# Algoritmo: [2.435533] | Original: 1.81
# Algoritmo: [2.435533] | Original: 1.81
# Algoritmo: [2.5535061] | Original: 1.81
# Algoritmo: [2.4355323] | Original: 1.81
# Algoritmo: [2.4355323] | Original: 1.8
# Algoritmo: [2.435533] | Original: 1.8
# Algoritmo: [2.435533] | Original: 1.8
# Algoritmo: [2.435533] | Original: 1.8
# Algoritmo: [4.8384943] | Original: 1.79
# Algoritmo: [2.435533] | Original: 1.79
# Algoritmo: [2.435533] | Original: 1.78
# Algoritmo: [2.435533] | Original: 1.78
# Algoritmo: [2.435533] | Original: 1.77
# Algoritmo: [2.435533] | Original: 1.77
# Algoritmo: [2.435533] | Original: 1.76
# Algoritmo: [2.435533] | Original: 1.76
# Algoritmo: [2.435533] | Original: 1.76
# Algoritmo: [2.435533] | Original: 1.76
# Algoritmo: [2.435533] | Original: 1.76
# Algoritmo: [2.435533] | Original: 1.76
# Algoritmo: [2.435533] | Original: 1.76
# Algoritmo: [2.435533] | Original: 1.76
# Algoritmo: [2.435533] | Original: 1.76
# Algoritmo: [2.435533] | Original: 1.76
# Algoritmo: [2.435533] | Original: 1.75
# Algoritmo: [2.435533] | Original: 1.75
# Algoritmo: [2.435533] | Original: 1.75
# Algoritmo: [2.435533] | Original: 1.75
# Algoritmo: [2.435533] | Original: 1.75
# Algoritmo: [2.435533] | Original: 1.75
# Algoritmo: [2.435533] | Original: 1.75
# Algoritmo: [2.435533] | Original: 1.74
# Algoritmo: [2.435533] | Original: 1.74
# Algoritmo: [2.435533] | Original: 1.74
# Algoritmo: [4.8384943] | Original: 1.74
# Algoritmo: [2.435533] | Original: 1.73
# Algoritmo: [2.4355323] | Original: 1.73
# Algoritmo: [2.435533] | Original: 1.73
# Algoritmo: [2.435533] | Original: 1.73
# Algoritmo: [2.435533] | Original: 1.73
# Algoritmo: [2.435533] | Original: 1.72
# Algoritmo: [2.435533] | Original: 1.72
# Algoritmo: [2.435533] | Original: 1.72
# Algoritmo: [2.435533] | Original: 1.72
# Algoritmo: [4.8384943] | Original: 1.72
# Algoritmo: [2.435533] | Original: 1.71
# Algoritmo: [2.435533] | Original: 1.71
# Algoritmo: [2.435533] | Original: 1.71
# Algoritmo: [2.435533] | Original: 1.71
# Algoritmo: [2.435533] | Original: 1.7
# Algoritmo: [2.435533] | Original: 1.7
# Algoritmo: [2.435533] | Original: 1.7
# Algoritmo: [2.435533] | Original: 1.7
# Algoritmo: [4.8384943] | Original: 1.7
# Algoritmo: [2.435533] | Original: 1.69
# Algoritmo: [4.8384943] | Original: 1.69
# Algoritmo: [2.435533] | Original: 1.69
# Algoritmo: [2.435533] | Original: 1.69
# Algoritmo: [2.435533] | Original: 1.69
# Algoritmo: [2.435533] | Original: 1.68
# Algoritmo: [2.435533] | Original: 1.68
# Algoritmo: [2.435533] | Original: 1.68
# Algoritmo: [4.8384943] | Original: 1.68
# Algoritmo: [2.435533] | Original: 1.68
# Algoritmo: [2.435533] | Original: 1.68
# Algoritmo: [2.435533] | Original: 1.67
# Algoritmo: [2.435533] | Original: 1.67
# Algoritmo: [2.435534] | Original: 1.67
# Algoritmo: [2.4355323] | Original: 1.67
# Algoritmo: [2.435533] | Original: 1.67
# Algoritmo: [2.4355352] | Original: 1.67
# Algoritmo: [2.435533] | Original: 1.67
# Algoritmo: [2.435533] | Original: 1.67
# Algoritmo: [2.435533] | Original: 1.67
# Algoritmo: [2.435533] | Original: 1.67
# Algoritmo: [4.8384943] | Original: 1.67
# Algoritmo: [2.435533] | Original: 1.67
# Algoritmo: [4.8384943] | Original: 1.66
# Algoritmo: [2.435533] | Original: 1.66
# Algoritmo: [2.4355345] | Original: 1.66
# Algoritmo: [2.435533] | Original: 1.66
# Algoritmo: [2.435533] | Original: 1.66
# Algoritmo: [2.435533] | Original: 1.66
# Algoritmo: [2.435533] | Original: 1.66
# Algoritmo: [2.435533] | Original: 1.66
# Algoritmo: [2.435533] | Original: 1.66
# Algoritmo: [4.8384943] | Original: 1.65
# Algoritmo: [2.435533] | Original: 1.65
# Algoritmo: [2.435533] | Original: 1.65
# Algoritmo: [2.435533] | Original: 1.65
# Algoritmo: [2.435533] | Original: 1.65
# Algoritmo: [2.435533] | Original: 1.65
# Algoritmo: [2.435533] | Original: 1.65
# Algoritmo: [2.435533] | Original: 1.64
# Algoritmo: [2.435533] | Original: 1.64
# Algoritmo: [2.435533] | Original: 1.64
# Algoritmo: [2.435533] | Original: 1.63
# Algoritmo: [2.435533] | Original: 1.63
# Algoritmo: [4.8384943] | Original: 1.63
# Algoritmo: [2.4355323] | Original: 1.63
# Algoritmo: [2.4355323] | Original: 1.63
# Algoritmo: [2.435533] | Original: 1.63
# Algoritmo: [2.435533] | Original: 1.62
# Algoritmo: [2.435533] | Original: 1.62
# Algoritmo: [2.435533] | Original: 1.62
# Algoritmo: [2.435533] | Original: 1.62
# Algoritmo: [2.435533] | Original: 1.62
# Algoritmo: [2.435533] | Original: 1.62
# Algoritmo: [2.435533] | Original: 1.62
# Algoritmo: [2.435533] | Original: 1.61
# Algoritmo: [2.435533] | Original: 1.61
# Algoritmo: [2.435533] | Original: 1.6
# Algoritmo: [2.435533] | Original: 1.6
# Algoritmo: [2.435533] | Original: 1.6
# Algoritmo: [2.435533] | Original: 1.6
# Algoritmo: [2.435533] | Original: 1.6
# Algoritmo: [2.435533] | Original: 1.59
# Algoritmo: [2.435533] | Original: 1.59
# Algoritmo: [2.435533] | Original: 1.59
# Algoritmo: [2.435533] | Original: 1.59
# Algoritmo: [2.435533] | Original: 1.59
# Algoritmo: [2.435533] | Original: 1.58
# Algoritmo: [2.435533] | Original: 1.58
# Algoritmo: [2.435533] | Original: 1.58
# Algoritmo: [2.435533] | Original: 1.58
# Algoritmo: [2.435533] | Original: 1.58
# Algoritmo: [2.435533] | Original: 1.58
# Algoritmo: [2.435533] | Original: 1.58
# Algoritmo: [2.435533] | Original: 1.57
# Algoritmo: [2.435533] | Original: 1.57
# Algoritmo: [2.435533] | Original: 1.57
# Algoritmo: [2.4355323] | Original: 1.57
# Algoritmo: [2.4355323] | Original: 1.57
# Algoritmo: [2.435533] | Original: 1.57
# Algoritmo: [2.435533] | Original: 1.57
# Algoritmo: [2.435533] | Original: 1.57
# Algoritmo: [2.435533] | Original: 1.57
# Algoritmo: [2.435533] | Original: 1.57
# Algoritmo: [2.435533] | Original: 1.56
# Algoritmo: [2.435533] | Original: 1.56
# Algoritmo: [2.435533] | Original: 1.56
# Algoritmo: [2.435533] | Original: 1.56
# Algoritmo: [2.435533] | Original: 1.56
# Algoritmo: [2.435533] | Original: 1.55
# Algoritmo: [2.435533] | Original: 1.55
# Algoritmo: [2.435533] | Original: 1.55
# Algoritmo: [2.435533] | Original: 1.55
# Algoritmo: [2.435533] | Original: 1.55
# Algoritmo: [2.435533] | Original: 1.55
# Algoritmo: [2.4362075] | Original: 1.55
# Algoritmo: [2.435533] | Original: 1.55
# Algoritmo: [2.435533] | Original: 1.54
# Algoritmo: [2.435533] | Original: 1.54
# Algoritmo: [2.435533] | Original: 1.54
# Algoritmo: [2.435533] | Original: 1.54
# Algoritmo: [2.435533] | Original: 1.54
# Algoritmo: [2.435533] | Original: 1.54
# Algoritmo: [2.435533] | Original: 1.53
# Algoritmo: [2.435533] | Original: 1.53
# Algoritmo: [2.435533] | Original: 1.53
# Algoritmo: [2.435533] | Original: 1.53
# Algoritmo: [2.435533] | Original: 1.53
# Algoritmo: [4.8384943] | Original: 1.53
# Algoritmo: [2.4355323] | Original: 1.52
# Algoritmo: [2.4355323] | Original: 1.52
# Algoritmo: [2.435533] | Original: 1.52
# Algoritmo: [2.435533] | Original: 1.52
# Algoritmo: [2.435533] | Original: 1.52
# Algoritmo: [2.435533] | Original: 1.51
# Algoritmo: [2.435533] | Original: 1.51
# Algoritmo: [2.435533] | Original: 1.51
# Algoritmo: [2.435533] | Original: 1.51
# Algoritmo: [2.435533] | Original: 1.51
# Algoritmo: [2.435533] | Original: 1.51
# Algoritmo: [2.435533] | Original: 1.51
# Algoritmo: [2.435533] | Original: 1.5
# Algoritmo: [2.435533] | Original: 1.5
# Algoritmo: [2.435533] | Original: 1.5
# Algoritmo: [2.435533] | Original: 1.5
# Algoritmo: [2.435533] | Original: 1.5
# Algoritmo: [2.435533] | Original: 1.5
# Algoritmo: [2.435533] | Original: 1.49
# Algoritmo: [2.435533] | Original: 1.49
# Algoritmo: [2.435533] | Original: 1.49
# Algoritmo: [2.435533] | Original: 1.49
# Algoritmo: [2.435533] | Original: 1.49
# Algoritmo: [2.435533] | Original: 1.49
# Algoritmo: [2.435533] | Original: 1.49
# Algoritmo: [2.435533] | Original: 1.48
# Algoritmo: [2.435533] | Original: 1.48
# Algoritmo: [2.435533] | Original: 1.48
# Algoritmo: [2.435533] | Original: 1.48
# Algoritmo: [2.435533] | Original: 1.48
# Algoritmo: [2.435533] | Original: 1.48
# Algoritmo: [2.435533] | Original: 1.48
# Algoritmo: [2.4355323] | Original: 1.48
# Algoritmo: [2.4355323] | Original: 1.48
# Algoritmo: [2.435533] | Original: 1.47
# Algoritmo: [2.435533] | Original: 1.47
# Algoritmo: [2.435533] | Original: 1.47
# Algoritmo: [2.435533] | Original: 1.46
# Algoritmo: [2.435533] | Original: 1.46
# Algoritmo: [2.435533] | Original: 1.46
# Algoritmo: [2.435533] | Original: 1.46
# Algoritmo: [2.435533] | Original: 1.46
# Algoritmo: [2.435533] | Original: 1.46
# Algoritmo: [2.435533] | Original: 1.45
# Algoritmo: [2.435533] | Original: 1.45
# Algoritmo: [2.435533] | Original: 1.45
# Algoritmo: [2.435533] | Original: 1.45
# Algoritmo: [2.4355364] | Original: 1.45
# Algoritmo: [2.435533] | Original: 1.45
# Algoritmo: [2.435533] | Original: 1.45
# Algoritmo: [2.435533] | Original: 1.44
# Algoritmo: [2.435533] | Original: 1.44
# Algoritmo: [2.435533] | Original: 1.44
# Algoritmo: [2.435533] | Original: 1.44
# Algoritmo: [2.435533] | Original: 1.44
# Algoritmo: [2.435533] | Original: 1.43
# Algoritmo: [2.435533] | Original: 1.43
# Algoritmo: [2.435533] | Original: 1.43
# Algoritmo: [2.435533] | Original: 1.43
# Algoritmo: [2.435533] | Original: 1.43
# Algoritmo: [2.435533] | Original: 1.43
# Algoritmo: [2.435533] | Original: 1.43
# Algoritmo: [2.435533] | Original: 1.43
# Algoritmo: [2.435533] | Original: 1.42
# Algoritmo: [2.4355323] | Original: 1.42
# Algoritmo: [4.8384943] | Original: 1.42
# Algoritmo: [2.435533] | Original: 1.42
# Algoritmo: [4.8384943] | Original: 1.42
# Algoritmo: [2.435533] | Original: 1.42
# Algoritmo: [2.435533] | Original: 1.42
# Algoritmo: [2.435533] | Original: 1.42
# Algoritmo: [2.435533] | Original: 1.42
# Algoritmo: [2.435533] | Original: 1.42
# Algoritmo: [2.435533] | Original: 1.42
# Algoritmo: [2.435533] | Original: 1.41
# Algoritmo: [2.435533] | Original: 1.41
# Algoritmo: [2.435533] | Original: 1.41
# Algoritmo: [2.435533] | Original: 1.41
# Algoritmo: [2.435533] | Original: 1.41
# Algoritmo: [2.435533] | Original: 1.41
# Algoritmo: [2.435533] | Original: 1.41
# Algoritmo: [2.435533] | Original: 1.4
# Algoritmo: [2.435533] | Original: 1.4
# Algoritmo: [2.435533] | Original: 1.4
# Algoritmo: [2.435533] | Original: 1.4
# Algoritmo: [2.435533] | Original: 1.4
# Algoritmo: [2.435533] | Original: 1.4
# Algoritmo: [2.435533] | Original: 1.4
# Algoritmo: [2.435533] | Original: 1.4
# Algoritmo: [2.435533] | Original: 1.4
# Algoritmo: [2.435533] | Original: 1.39
# Algoritmo: [2.435533] | Original: 1.39
# Algoritmo: [2.435533] | Original: 1.38
# Algoritmo: [2.435533] | Original: 1.38
# Algoritmo: [2.435533] | Original: 1.38
# Algoritmo: [2.435533] | Original: 1.38
# Algoritmo: [4.8384943] | Original: 1.38
# Algoritmo: [2.4355323] | Original: 1.38
# Algoritmo: [4.8384943] | Original: 1.38
# Algoritmo: [2.435533] | Original: 1.38
# Algoritmo: [2.435533] | Original: 1.38
# Algoritmo: [2.435533] | Original: 1.38
# Algoritmo: [2.435533] | Original: 1.37
# Algoritmo: [2.435533] | Original: 1.37
# Algoritmo: [2.435533] | Original: 1.37
# Algoritmo: [2.435533] | Original: 1.37
# Algoritmo: [2.435533] | Original: 1.37
# Algoritmo: [2.435533] | Original: 1.37
# Algoritmo: [2.435533] | Original: 1.37
# Algoritmo: [2.435533] | Original: 1.36
# Algoritmo: [2.435533] | Original: 1.36
# Algoritmo: [2.435533] | Original: 1.36
# Algoritmo: [2.435533] | Original: 1.36
# Algoritmo: [2.435533] | Original: 1.36
# Algoritmo: [2.435533] | Original: 1.36
# Algoritmo: [2.435533] | Original: 1.36
# Algoritmo: [2.435533] | Original: 1.35
# Algoritmo: [2.435533] | Original: 1.35
# Algoritmo: [2.435533] | Original: 1.35
# Algoritmo: [2.435533] | Original: 1.35
# Algoritmo: [2.435533] | Original: 1.35
# Algoritmo: [2.435533] | Original: 1.35
# Algoritmo: [2.435533] | Original: 1.35
# Algoritmo: [4.8384943] | Original: 1.35
# Algoritmo: [2.435533] | Original: 1.35
# Algoritmo: [2.435533] | Original: 1.35
# Algoritmo: [2.435533] | Original: 1.35
# Algoritmo: [2.435533] | Original: 1.35
# Algoritmo: [2.4355323] | Original: 1.34
# Algoritmo: [2.4355323] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.435533] | Original: 1.34
# Algoritmo: [2.4975514] | Original: 1.33
# Algoritmo: [2.435533] | Original: 1.33
# Algoritmo: [2.435533] | Original: 1.33
# Algoritmo: [2.435533] | Original: 1.33
# Algoritmo: [2.435533] | Original: 1.32
# Algoritmo: [2.435533] | Original: 1.32
# Algoritmo: [2.435533] | Original: 1.32
# Algoritmo: [2.435533] | Original: 1.32
# Algoritmo: [2.4355333] | Original: 1.32
# Algoritmo: [2.435533] | Original: 1.32
# Algoritmo: [2.435533] | Original: 1.32
# Algoritmo: [2.435533] | Original: 1.32
# Algoritmo: [2.435533] | Original: 1.31
# Algoritmo: [2.435533] | Original: 1.31
# Algoritmo: [2.435533] | Original: 1.31
# Algoritmo: [4.8384943] | Original: 1.31
# Algoritmo: [2.4355323] | Original: 1.31
# Algoritmo: [2.435533] | Original: 1.31
# Algoritmo: [2.435533] | Original: 1.31
# Algoritmo: [2.435533] | Original: 1.3
# Algoritmo: [2.435533] | Original: 1.3
# Algoritmo: [2.435533] | Original: 1.3
# Algoritmo: [2.435533] | Original: 1.3
# Algoritmo: [2.435533] | Original: 1.3
# Algoritmo: [2.435533] | Original: 1.3
# Algoritmo: [2.435533] | Original: 1.3
# Algoritmo: [2.435533] | Original: 1.29
# Algoritmo: [2.435533] | Original: 1.29
# Algoritmo: [2.435533] | Original: 1.29
# Algoritmo: [2.435533] | Original: 1.29
# Algoritmo: [2.435533] | Original: 1.29
# Algoritmo: [2.435533] | Original: 1.29
# Algoritmo: [2.435533] | Original: 1.29
# Algoritmo: [2.435533] | Original: 1.29
# Algoritmo: [4.6642284] | Original: 1.29
# Algoritmo: [2.435533] | Original: 1.29
# Algoritmo: [2.435533] | Original: 1.29
# Algoritmo: [2.435533] | Original: 1.29
# Algoritmo: [2.435533] | Original: 1.28
# Algoritmo: [2.435533] | Original: 1.28
# Algoritmo: [2.435533] | Original: 1.28
# Algoritmo: [2.435533] | Original: 1.28
# Algoritmo: [2.435533] | Original: 1.28
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.4355373] | Original: 1.27
# Algoritmo: [2.4355323] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [4.8384943] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.27
# Algoritmo: [2.435533] | Original: 1.26
# Algoritmo: [2.435533] | Original: 1.26
# Algoritmo: [2.435533] | Original: 1.26
# Algoritmo: [2.435533] | Original: 1.26
# Algoritmo: [2.435533] | Original: 1.26
# Algoritmo: [2.435533] | Original: 1.25
# Algoritmo: [2.435533] | Original: 1.25
# Algoritmo: [2.435533] | Original: 1.25
# Algoritmo: [2.435533] | Original: 1.25
# Algoritmo: [2.435533] | Original: 1.25
# Algoritmo: [2.435533] | Original: 1.25
# Algoritmo: [2.435533] | Original: 1.25
# Algoritmo: [2.435533] | Original: 1.25
# Algoritmo: [2.435533] | Original: 1.25
# Algoritmo: [2.435533] | Original: 1.25
# Algoritmo: [2.435533] | Original: 1.25
# Algoritmo: [2.4355323] | Original: 1.25
# Algoritmo: [2.4355323] | Original: 1.25
# Algoritmo: [2.435533] | Original: 1.25
# Algoritmo: [2.435533] | Original: 1.24
# Algoritmo: [2.435533] | Original: 1.24
# Algoritmo: [2.435533] | Original: 1.24
# Algoritmo: [2.435533] | Original: 1.24
# Algoritmo: [2.435533] | Original: 1.24
# Algoritmo: [2.435533] | Original: 1.24
# Algoritmo: [2.435533] | Original: 1.24
# Algoritmo: [2.435533] | Original: 1.24
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.23
# Algoritmo: [2.435533] | Original: 1.22
# Algoritmo: [2.435533] | Original: 1.22
# Algoritmo: [2.435533] | Original: 1.22
# Algoritmo: [2.435533] | Original: 1.22
# Algoritmo: [2.435533] | Original: 1.22
# Algoritmo: [2.435533] | Original: 1.22
# Algoritmo: [2.435533] | Original: 1.21
# Algoritmo: [2.4355323] | Original: 1.21
# Algoritmo: [2.4355323] | Original: 1.21
# Algoritmo: [2.435533] | Original: 1.21
# Algoritmo: [2.435533] | Original: 1.21
# Algoritmo: [2.435533] | Original: 1.21
# Algoritmo: [2.435533] | Original: 1.21
# Algoritmo: [2.435533] | Original: 1.21
# Algoritmo: [2.435533] | Original: 1.21
# Algoritmo: [2.435533] | Original: 1.21
# Algoritmo: [2.435533] | Original: 1.21
# Algoritmo: [2.435533] | Original: 1.21
# Algoritmo: [2.435533] | Original: 1.21
# Algoritmo: [2.435533] | Original: 1.21
# Algoritmo: [2.435533] | Original: 1.21
# Algoritmo: [2.435533] | Original: 1.2
# Algoritmo: [2.435533] | Original: 1.2
# Algoritmo: [2.435533] | Original: 1.2
# Algoritmo: [2.435533] | Original: 1.2
# Algoritmo: [2.435533] | Original: 1.2
# Algoritmo: [2.435533] | Original: 1.2
# Algoritmo: [2.435533] | Original: 1.2
# Algoritmo: [2.435533] | Original: 1.2
# Algoritmo: [2.435533] | Original: 1.2
# Algoritmo: [2.435533] | Original: 1.19
# Algoritmo: [2.435533] | Original: 1.19
# Algoritmo: [2.435533] | Original: 1.19
# Algoritmo: [2.435533] | Original: 1.19
# Algoritmo: [2.435533] | Original: 1.19
# Algoritmo: [2.435533] | Original: 1.19
# Algoritmo: [2.435533] | Original: 1.19
# Algoritmo: [2.435533] | Original: 1.19
# Algoritmo: [2.435533] | Original: 1.19
# Algoritmo: [2.4355323] | Original: 1.19
# Algoritmo: [2.4355323] | Original: 1.18
# Algoritmo: [2.435533] | Original: 1.18
# Algoritmo: [2.435533] | Original: 1.18
# Algoritmo: [2.435533] | Original: 1.18
# Algoritmo: [2.4355345] | Original: 1.18
# Algoritmo: [2.435533] | Original: 1.18
# Algoritmo: [2.435533] | Original: 1.17
# Algoritmo: [2.435533] | Original: 1.17
# Algoritmo: [2.435533] | Original: 1.17
# Algoritmo: [2.435533] | Original: 1.17
# Algoritmo: [2.435533] | Original: 1.17
# Algoritmo: [2.435533] | Original: 1.17
# Algoritmo: [2.435533] | Original: 1.17
# Algoritmo: [4.8384943] | Original: 1.17
# Algoritmo: [4.8384943] | Original: 1.17
# Algoritmo: [2.435533] | Original: 1.17
# Algoritmo: [2.435533] | Original: 1.17
# Algoritmo: [2.435533] | Original: 1.17
# Algoritmo: [4.8384943] | Original: 1.17
# Algoritmo: [2.435533] | Original: 1.17
# Algoritmo: [2.435533] | Original: 1.16
# Algoritmo: [2.435533] | Original: 1.16
# Algoritmo: [2.435533] | Original: 1.16
# Algoritmo: [2.435533] | Original: 1.16
# Algoritmo: [2.435533] | Original: 1.16
# Algoritmo: [2.435533] | Original: 1.16
# Algoritmo: [2.435533] | Original: 1.16
# Algoritmo: [2.435533] | Original: 1.16
# Algoritmo: [2.435533] | Original: 1.16
# Algoritmo: [2.435533] | Original: 1.16
# Algoritmo: [2.435533] | Original: 1.16
# Algoritmo: [2.4355323] | Original: 1.15
# Algoritmo: [2.4355323] | Original: 1.15
# Algoritmo: [2.435533] | Original: 1.15
# Algoritmo: [2.435533] | Original: 1.15
# Algoritmo: [2.435533] | Original: 1.15
# Algoritmo: [2.435533] | Original: 1.15
# Algoritmo: [2.435533] | Original: 1.15
# Algoritmo: [2.435533] | Original: 1.15
# Algoritmo: [4.8384943] | Original: 1.15
# Algoritmo: [2.435533] | Original: 1.15
# Algoritmo: [2.435533] | Original: 1.15
# Algoritmo: [2.435533] | Original: 1.14
# Algoritmo: [2.435533] | Original: 1.14
# Algoritmo: [2.435533] | Original: 1.14
# Algoritmo: [2.435533] | Original: 1.14
# Algoritmo: [2.435533] | Original: 1.14
# Algoritmo: [2.435533] | Original: 1.14
# Algoritmo: [2.435533] | Original: 1.14
# Algoritmo: [2.435533] | Original: 1.14
# Algoritmo: [2.435533] | Original: 1.14
# Algoritmo: [2.435533] | Original: 1.14
# Algoritmo: [2.4442465] | Original: 1.14
# Algoritmo: [2.435533] | Original: 1.14
# Algoritmo: [2.435533] | Original: 1.14
# Algoritmo: [2.435533] | Original: 1.13
# Algoritmo: [2.435533] | Original: 1.13
# Algoritmo: [2.435533] | Original: 1.13
# Algoritmo: [2.435533] | Original: 1.13
# Algoritmo: [2.435533] | Original: 1.13
# Algoritmo: [2.435533] | Original: 1.13
# Algoritmo: [2.435533] | Original: 1.13
# Algoritmo: [2.435533] | Original: 1.13
# Algoritmo: [2.4355323] | Original: 1.13
# Algoritmo: [2.4355323] | Original: 1.13
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [4.8384943] | Original: 1.12
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [2.435533] | Original: 1.12
# Algoritmo: [4.8384943] | Original: 1.11
# Algoritmo: [2.435533] | Original: 1.11
# Algoritmo: [2.435533] | Original: 1.11
# Algoritmo: [2.435533] | Original: 1.11
# Algoritmo: [2.435533] | Original: 1.11
# Algoritmo: [2.435533] | Original: 1.11
# Algoritmo: [2.435533] | Original: 1.11
# Algoritmo: [2.435533] | Original: 1.11
# Algoritmo: [2.435533] | Original: 1.1
# Algoritmo: [2.435533] | Original: 1.1
# Algoritmo: [2.435533] | Original: 1.1
# Algoritmo: [2.435533] | Original: 1.1
# Algoritmo: [2.435533] | Original: 1.1
# Algoritmo: [2.435533] | Original: 1.1
# Algoritmo: [2.435533] | Original: 1.1
# Algoritmo: [2.4355323] | Original: 1.1
# Algoritmo: [2.4355323] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.09
# Algoritmo: [2.435533] | Original: 1.08
# Algoritmo: [2.435533] | Original: 1.08
# Algoritmo: [4.8384943] | Original: 1.08
# Algoritmo: [2.435533] | Original: 1.08
# Algoritmo: [2.435533] | Original: 1.08
# Algoritmo: [2.435533] | Original: 1.08
# Algoritmo: [2.435533] | Original: 1.08
# Algoritmo: [2.435533] | Original: 1.08
# Algoritmo: [2.435533] | Original: 1.08
# Algoritmo: [2.435533] | Original: 1.08
# Algoritmo: [2.435533] | Original: 1.08
# Algoritmo: [2.435533] | Original: 1.07
# Algoritmo: [2.435533] | Original: 1.07
# Algoritmo: [2.435533] | Original: 1.07
# Algoritmo: [2.435533] | Original: 1.07
# Algoritmo: [2.4355323] | Original: 1.07
# Algoritmo: [2.4355323] | Original: 1.07
# Algoritmo: [2.435533] | Original: 1.07
# Algoritmo: [2.435533] | Original: 1.07
# Algoritmo: [2.435533] | Original: 1.07
# Algoritmo: [2.435533] | Original: 1.07
# Algoritmo: [2.435533] | Original: 1.07
# Algoritmo: [2.435533] | Original: 1.07
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.06
# Algoritmo: [2.435533] | Original: 1.05
# Algoritmo: [2.435533] | Original: 1.05
# Algoritmo: [2.435533] | Original: 1.05
# Algoritmo: [2.435533] | Original: 1.05
# Algoritmo: [2.4355323] | Original: 1.05
# Algoritmo: [2.4355323] | Original: 1.05
# Algoritmo: [2.435533] | Original: 1.05
# Algoritmo: [2.435533] | Original: 1.05
# Algoritmo: [2.435533] | Original: 1.05
# Algoritmo: [2.435533] | Original: 1.05
# Algoritmo: [2.435533] | Original: 1.05
# Algoritmo: [2.435533] | Original: 1.05
# Algoritmo: [2.435533] | Original: 1.04
# Algoritmo: [2.435533] | Original: 1.04
# Algoritmo: [2.435533] | Original: 1.04
# Algoritmo: [2.435533] | Original: 1.04
# Algoritmo: [2.435533] | Original: 1.04
# Algoritmo: [2.435533] | Original: 1.04
# Algoritmo: [2.435533] | Original: 1.04
# Algoritmo: [2.435533] | Original: 1.04
# Algoritmo: [2.435533] | Original: 1.04
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [4.8384943] | Original: 1.03
# Algoritmo: [2.435533] | Original: 1.03
# Algoritmo: [2.4355323] | Original: 1.03
# Algoritmo: [2.4355323] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.02
# Algoritmo: [2.435533] | Original: 1.01
# Algoritmo: [2.435533] | Original: 1.01
# Algoritmo: [2.435533] | Original: 1.01
# Algoritmo: [2.435533] | Original: 1.01
# Algoritmo: [2.435533] | Original: 1.01
# Algoritmo: [2.435533] | Original: 1.01
# Algoritmo: [2.435533] | Original: 1.01
# Algoritmo: [2.4355326] | Original: 1.01
# Algoritmo: [2.4355326] | Original: 1.01
# Algoritmo: [2.4355326] | Original: 1.01

# %% [markdown]
# ### Alguma Dúvida? Entre em Contato Comigo:

# %% [markdown]
# - [Me envie um e-mail](mailto:alysson.barbosa@ee.ufcg.edu.br);
